# %% [markdown]
# <a href="https://colab.research.google.com/github/nickwharff/CS167_Notes/blob/main/Day12_web_scraper.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Let's Scrape some Fantasy Character Names
#
# ## Brando Sando Style:
#
# Let's scrape the names from Brandon Sanderson Characters found on [this website](https://coppermind.net/wiki/Category:Characters).
#
# Let's start by importing Beautiful soup and providing the URL pointing to the webpage. We use the `requests` library to get the text from the html.

# %%
from bs4 import BeautifulSoup
import requests
import csv

source = requests.get('https://coppermind.net/wiki/Category:Characters').text

soup = BeautifulSoup(source, 'html.parser')

# open the file that we want to save our data to
csv_file = open('fantasy_characters.csv', 'w') # creating a new file that you will save results to
csv_writer = csv.writer(csv_file)

# decide what data you want to save, and create the header row
csv_writer.writerow(['name', 'author','genre', 'series', 'description']) 

# print(soup.prettify())
# Out:
# 38

# %% [markdown]
# # Webscraping tutorial
# - Right click -> inspect
# - Find class that has all of the data that you want in it
# -

# %% [markdown]
# Since the names are stored in `li`'s, we will use the `soup.find_all` function and provide the argument `li`. This will find all of the list items on the page. This is a good first step, but you'll notice, it's not quite what we want--it includes the list items before the actual charatcter names.
#
# Also, notice the line `li.text`. We are going through and getting each list item, and then only looking at the text (the `.text` line indicates this).

# %%
for li in soup.find_all('li'):
  print(li.text)
# Out:
# Alcatraz
# Elantris & The Emperor's Soul
# Legion
# Mistborn series
# The Reckoners
# Rithmatist
# Shadows for Silence in the Forests of Hell
# Sixth of the Dusk
# The Stormlight Archive
# Warbreaker
# White Sand
# Characters who have died
# Characters who use magic
# Characters who are sailors
# Characters who are scholars
# Characters who have no canonical name
# Characters with point of view narratives
# Groups or organizations of characters
# Characters by ethnicity or nationality
# ►  Alcatraz characters‎ (5 C, 44 P)
# ►  Dark One characters‎ (27 P)
# ►  Dead characters‎ (380 P)
# ►  Dreamer characters‎ (8 P)
# ►  Ethnicities and Nationalities‎ (51 C, 71 P)
# ►  Family names‎ (36 P)
# ►  Given names‎ (109 P)
# ►  Groups‎ (38 C, 126 P)
# ►  Legion characters‎ (52 P)
# ►  Magic users‎ (26 C, 52 P)
# ►  Professions‎ (8 C, 4 P)
# ►  Reckoners characters‎ (136 P, 18 F)
# ►  Residents‎ (27 C)
# ►  Rithmatist characters‎ (69 P)
# ►  Snapshot characters‎ (17 P)
# ►  Titled characters‎ (38 P)
# ►  Unnamed characters‎ (41 P)
# ►  Viewpoint characters‎ (135 P)
# Aarik
# Aaron
# Abaray
# Abiajan
# Abigail Casey
# Abraham Desjardins
# Abrem
# Abrial
# Abrobadar
# Abronai
# Abry
# Absence
# Acis
# Acumidian delver
# Adam Li
# Adam Makings
# Adawathwyn
# Adelle Choi
# Adi
# Adien
# Adin
# Adis
# Adolin Kholin
# Adoline
# Adonalsium
# Adrotagia
# Aeo
# Aesudan Kholin
# Agil
# Ahan
# Aharat
# Ahmes
# Ais
# Ala
# Alabet
# Aladar
# Alai
# Alakavish
# Alalan
# Alalhawithador
# Alanik
# Alavah
# Alaward
# Alaxia
# Alazansi
# Alcatraz Smedry
# Alds
# Aledin
# Alendi
# Alernath
# Alezarv
# Alfir
# Algernon Weight
# Ali-daughter-Hasweth
# Alili
# Alim
# Allahn
# Allekatrase
# Allik Neverfar
# Allmother
# Alloran Feltri
# Allri Innate
# Allriandre Durkel
# Allrianne Cett
# Allrianne's mother
# Alonoe
# Alstben
# Altoki
# Aluki
# Aluko
# Alvettaren
# Amala
# Amaranta
# Amark
# Ambrian
# Amuna
# Ana
# Andrew Nalizar
# Andy Blackwell
# Anesa
# Angola Dartmoor
# Ann
# Annarel
# Anola
# Anthony Davis
# Antillius Shezler
# Antique
# Aona
# Apara
# Ape Manton
# Aqqu
# Aradan Yomen
# Arafik
# Aramine
# Aratin Khal
# Arbitan
# Archedis
# Archinal
# Arclomedarian
# Ardous Geffenry
# Aria
# Aric
# Arik
# Arintol
# Armal
# Armando
# Armsman
# Arnaud
# Arriev
# Arshqqam
# Arsteel
# Artmyrn
# Arturo Mendez
# Ashe
# Ashelem
# Ashertmarn
# Ashgress
# Ashir
# Ashlv
# Ashno
# Ashravan
# Ashu
# Ashweather Cett
# Ashwin
# Aslydin
# Asthta-daughter-Methista
# Atara
# Ati
# Ati (seon)
# Atlas Butler
# Atsuko
# Attica Smedry
# Attin Balazmed
# Au-lam
# Au-nak
# Audil Lekal
# Audrey
# Augustin Tekiel
# Aunt Gin
# Aunt Glorf
# Ausdenec
# Australia Smedry
# Austre
# Av
# Avado
# Avarak Matal
# Avaran
# Avena
# Aving Cett
# Axies
# Axikk
# Axindweth
# Aya
# Aydee Ecks Smedry
# Azalec
# Azure
# B. Sablerfils
# Ba-Ado-Mishram
# Backbreaker
# Badali
# Bahmen
# Balat Davar
# Balsas
# Balubal Razon
# Banks
# Baon
# Barb
# Barkley
# Barl
# Barlesha Lhan
# Barm
# Barmest
# Bashin
# Basin Bill
# Bastien Severington
# Bastille
# Bastion
# Bat'Chor
# Battar
# Bavadin
# Bavamar
# Baxil
# Beal
# Beard
# Beautiful Song
# Bebid
# Becca Nightshade
# Bedes
# Beggar (Kasitor)
# Bek
# Bekenah
# Beld
# Beldre
# Ben Oldson
# Bendal
# Bendthel
# Benneh
# Bennitson
# Berbrath
# Beryl
# Besk
# Betha
# Bethab
# Bettam
# Bevidon
# Beznk
# Biblioden
# Bidlel
# Bila
# Bilg
# Bilko
# Bilmy
# Bim
# Bisig
# Blain Charleston
# Blantach
# Blaze
# Bleaker
# Blended
# Blinker
# Blome
# Bloody Kent
# Bloody Tan
# Blue
# Blushweaver
# Bluth
# Bob (Skyward)
# Bob (The Original)
# Bog
# Bookers
# Boomslug
# Bordin
# Borea
# Boriar
# Boris Junior
# Boris the Third
# Braches
# Brade Shimabukuro
# Brainstorm
# Brakah
# Brekv
# Brell
# Brettin
# Brianlia
# Brick
# Brig Dartmoor
# Briggen
# Briggs
# Brighthue
# Brightlord Morakotha
# Brightlord Seveks
# Brightvision
# Brill
# Broken Wind
# Bru
# Brunswick
# Bryn
# Buissonommes
# Burl (character)
# Burlow
# Bussik
# Cabe
# Caberel
# Cabine
# Cadilar
# Cadon
# Cads
# Caeb
# Cael
# Caelinora
# Calaka
# Calamity (Epic)
# Cali
# Cali Hatthew
# Calinam
# Call
# Caller of Springs
# Calling War
# Callins
# Callins Geffenry
# Calmseer
# Camon
# Campbell
# Captain of the Oot's Dream
# Carl Newton
# Carla
# Carlee
# Carmine Feltry
# Cassileux
# Caull
# Cenn
# Cessil
# Cett (coach owner)
# Chamrav
# Chanada
# Chananar
# Chanarach
# Chanasha Hasareh
# Chanrm
# Chapaou
# Chapmot Heviers
# Charisa of Utaries
# Charles
# Charles Calloway
# Charlie
# Charlie's father
# Charlington
# Charrs Entrone
# Chaz
# Cheeky
# Chemoarish
# Chesterton Divide
# Chet
# Chief Roberts
# Chilinko
# Chip (constable)
# Chip (hunter)
# Chip Erikell
# Chiri-Chiri
# Chivi
# Chowyun Chin
# Chubs
# Cimines
# Cladent
# Clamps
# Clapper
# Claude Aradel
# Cled
# Cleft-chin
# Clive
# Cloak
# Clod
# Clotide
# Cloudbreaker
# Cob (Mistborn)
# Cob (Stormlight)
# Cobble
# Cody
# Coldwin
# Coleman Stewart
# Coln Abrams
# Colot
# Condwish
# Conrad
# Copper Strangler
# Corberon
# Corbin
# Cord
# Coreb
# Corgi
# Corl
# Cormshen
# Corvana
# Cosahn
# Court Judge
# Coussaint
# Creer
# Creer boys
# Crenda
# Cressa
# Crews Geffenry
# Crossmark
# Crow
# Crystallix (Epic)
# Culee
# Cuna
# Curveball
# Cusicesh
# Cyn
# Cynder
# Da
# Daal
# Dabbid
# Daggon
# Dahad
# Dai-Gonarthis
# Daius
# Dakhnah
# Dalar
# Dali
# Dalinar Kholin
# Dalinar's father
# Dalksi
# Dallet
# Dan
# Dandos Heraldin
# Danlan Morakotha
# Dao
# Daora
# Daorn
# Darcira
# Darkness Infinity
# Darkwater
# Darla Mee-Bim
# Darlin Cett
# Darm (Mistborn)
# Darm (Rithmatist)
# Darriance
# Dashe
# Dashir boys
# Daughnin
# Davenport
# David Charleston
# Davim
# Davis
# Dawnslight
# Daystorm
# Dead Drop
# Dean
# Dean Knighthawk
# Deathpoint
# Deathrise
# Dechamp
# Dechane
# Dedelin
# Dedri Vasting
# Deedanor
# Deeli
# Delgo
# Delius
# Delius's son
# Delp
# Delph
# Deluse Couvre
# Dem
# Demid
# Demmy
# Demoux
# Den
# Denise Carlson
# Dennison Crestmar
# Denshil
# Dent
# Denth
# Deral
# Dereth
# Derethil
# Design
# Destra
# Detor
# Devi
# Devin
# Devinshae
# Devlin Airs
# Devmrh
# Dia Vmeer
# Dialas
# Dialectur
# Diamond
# Dianil
# Diaz
# Didrich Calloway
# Dieno
# Diggen
# Digzone
# Dilaf
# Dilid
# Dilisteni
# Dims
# Dink
# Dio
# Diolen
# Dion
# Dion Maheras
# Diren
# Dirin
# Dirk
# Disten
# Dlavil
# Dllllizzzz
# Dob
# Dobsi
# Doc Slush
# Dockson
# Dod
# Dodger
# Dok
# Dolimid
# Donal
# Donny
# Donton
# Doomslug
# Dor (character)
# Doran
# Dorgo
# Dorise Chevalle
# Dorolin
# Dorp
# Dothgen
# Doug
# Douglas
# Douglas Venture
# Dovcanti
# Dowser Maline
# Dr. Marcus
# Dragdown
# Drama
# Drape
# Drapen
# Draulin
# Drawers
# Dreamer (character)
# Dreaming-though-Awake
# Dreder
# Drehy
# Drenya
# Drewton
# Dridel
# Drile
# Drim
# Drlwan
# Droz
# Dru
# Druffel
# Drummer brothers
# Duane
# Dug
# Dukaler
# Dukar
# Dul
# Dumad
# Dunny
# Dupon Melstrom
# Durk
# Durkel
# Durn
# Durnash
# Durton
# Duskwatch
# Dylan
# Dym
# Dynamo
# Earless
# Edan
# Eddie Macano
# Edgard Ladrian
# Edgli
# Edip
# Edmund (Cytonic)
# Edmund Sense
# Edso
# Edwarn Ladrian
# Ehelan
# Ehen
# Ekel
# El
# El Brass Bullish Dude
# Elao
# Elashe
# Eldon
# Electrodyne
# Elend Venture
# Elend's mother
# Eleseth
# Elhokar Kholin
# Elit Ruthar
# Eliza Marin
# Elizabeth Warner
# Elizandra Dramali
# Ellista
# Elorin
# Elors Durnsed
# Elrao
# Elthebar
# Embrier
# Mrs. Emuishere
# En
# Enelan
# Enrique Estevez
# Eoden
# Eoldess
# Eondel
# Eonic
# Epinar
# Eranniv
# Eriola
# Eshava
# Eshen
# Eshonai
# Eshu
# Essu
# Estnatil
# Eth
# Ethid
# Eton
# Eusto
# Eva Winters
# Evenstrom Tekiel
# Eventeo
# Eventire
# Evi Kholin
# Evinor
# Evod Markmaker
# Exel
# Extes
# Exton L. Pratt
# Eylita Tavinar
# Fabergé
# Fabrisan
# Fafen
# Falilar
# Falksi
# Fari
# Faridai
# Father Bin
# Fathom (Epic)
# Fatren
# Faultline
# User:Fbstj/t:char
# Febin
# Febrth
# Fed
# Fedik
# Fedre
# Fedren Aime
# Feldeu
# Felise Demoux
# Fellette Renoux
# Felt
# Fen Rnamdi
# Feotora
# Feral
# Ferson Penrod
# FhorKood
# Fia
# Fialia
# Fiksin
# Fimkn
# Fin
# Fine
# Finis
# Finn Elstin
# Fion
# First of the Sky
# Fisk
# Fitch
# Fitzroy
# Fjon
# Fladm
# Flatik
# Flavine
# Fleet
# Fleeta
# Flen
# Flend
# Flik
# Flip
# Flog
# Florence
# Florin Malin
# Fob
# Foil
# Folsom Smedry
# Forch
# Forgeron
# Fort
# Forton
# Fortuity
# Fran
# Franis
# Franson
# Frava
# Frederique Gorski
# Freudland
# Freyja Marten
# Fronks Vif
# Frost
# Fuego
# Fyld
# Gabrathin
# Gabria
# Gadol
# Gagaril
# Galabris Menthon
# Galan
# Galbrometh
# Galid
# Galivan
# Galladon
# Gallam
# Gallant
# Gallingskaw
# Gangnah
# Ganlos Riera
# Gaotona
# Gare
# Garisel Daring
# Garv
# Gashash-son-Navammis
# Gatrii
# Gavam
# Gavarah
# Gavashaw
# Gave Entrone
# Gavilar Kholin
# Gavinor Kholin
# Gavri
# Gaz
# Gemdwyn
# Gemmel
# Gen
# Gendren
# Genedere
# General Khal
# Gennel
# Geoff Hamilton
# George
# Geormin
# Gerald Taffington
# Geranid
# Gereh
# Gereh's Aviar
# Gerrig
# Getruda
# Getrue
# Gevalden
# Geved
# Gevelmar
# Ghenna
# Gibsey
# Gift
# Giftbeacon
# Gilaf
# Gill
# Gina Gutierrez
# Gitgeth
# Glen
# Glimmer
# Glurv
# Glys
# Gnash the Slaughterer
# Gneorndin Cett
# Godeke
# Gol
# Golombi
# Gom
# Gor
# Goradel
# Gord
# Gorglen
# Goro
# Goshel
# Gosovic
# Grable
# Graeo
# Granite Joe
# Granks
# Graves
# Graviton
# Great-grandmother Glorf
# Greg
# Gregorh
# Gregory III
# Gregr
# Grelin
# Gremm
# Gremmy
# Gremt
# Grent
# Gret
# Grondkest
# Grund
# Gu
# Gub
# Guff
# Guillian
# Gul'zah
# Gulastis
# Guntua
# Gustal
# Guvlow
# Guyn
# Gvori
# Gward
# Gyro
# Hab
# Habatab
# Haberstock
# Habrin
# Habsant
# Haddek
# Hadinar
# Hadren Renoux
# Hal Davis
# Halad
# Halam Khal
# Halan
# Halbeth
# Hallaw
# Hamadin
# Hamaradin
# Hamel
# Hammie
# Hammond
# Han ShuXen
# Hana
# Hanavanar
# Handerwym
# Hanlanaze
# Haona
# Happy
# Harathdal
# Harding
# Hardren
# Harel
# Hariel
# Harkaylain
# Harl
# Harmon
# Harold
# HARRE
# Harris
# Harrisel Hard
# Harrison
# Harth
# Harvo
# Hasavah
# Hashal
# Hasheh
# Hatch
# Hatham
# Hathan
# Hauka
# Hav
# Havakal
# Havar
# Havarah
# Havarseth
# Havrom
# Hawin
# Hawkham
# Haws
# Heb
# Heberen
# Heelis
# Heimline
# Helaran Davar
# Helenntion
# Helium
# Helt
# Hem
# Hema-Dak
# Hennin
# Herman Libel
# Hershel Black
# Herve
# Hesh
# Hesho
# Hesina
# Hessi
# Hettel
# Hextilda McTavish
# Hid
# High Emperor
# Hilde
# Himalaya Smedry
# Hinston Ladrian
# Hmalka
# Hnanan
# Hobart
# Hobber
# Hoid
# Holly Martinez
# Holly Winseed (Original)
# Holly Winseed (Provisional Replica)
# Holmes
# Hong
# Hopefinder
# Horace
# Horen
# Horinar
# Hoselle
# Howards
# Hrathen
# Hrathen's seon
# Hrdalm
# Hrud
# Hudiya
# Hughes Entrone
# Huio
# Huisi
# HunFoor
# Huqin
# Hurli
# Husal
# Iadon
# Ialai Sadeas
# Icer
# Ico
# Ico's father
# Idan
# Idani
# Idashwy
# Ides Hatred
# Ido
# Idolir
# Idotris
# Idren Seeris
# Idrin
# Ien
# Iglom
# Ignacio
# Ilamar
# Illarion
# Inabar
# Inadara
# Infinity
# Inhanna
# Inin
# Inis Julien
# Inkima
# Inkspren shopkeeper
# Inkwell (Epic)
# Innia
# Insah
# Inshallah
# Instabam
# Insulation
# Invia
# Invocation
# Irich
# Isabaline Frellia
# Isabi
# Isadan Sao
# Isan
# Isasik Shulin
# Ishal
# Ishar
# Ishikk
# Ishnah
# Isom
# Istow
# Ithi
# Ivanar Ruthar
# Ivans
# Ivis
# Ivory
# Ivy
# Ixil
# Ixsix
# Iyalid
# Iyatil
# J.C.
# Jackstom Harms
# Jacques Cartier
# Jadendwyl
# Jager
# Jak
# Jakamav
# Jaks
# Jal Mala
# Jali
# Jalla
# Jam (Hearthstone)
# Jam (caravaneer)
# James Hovell
# Jammi Walls
# Jamms
# Jan Ven
# Janala Lustow
# Janarle
# Janie
# Jarel
# Jarloux
# Jarrington
# Jasalai
# Jasmine
# Jasnah Kholin
# Jason Write
# Jasson
# Jasten
# Jastes Lekal
# Jaston
# Javie
# Javier DaLeuc
# Javies
# Javih
# Jax (Reckoners)
# Jax (Skyward)
# Jaxlim
# Jaxy
# Jayla Ruthar
# Jeber
# Jed
# Jedal
# Jedan
# Jeffy
# Jeksonofnone
# Jell
# Jendel
# Jendellah
# Jenet
# Jenin
# Jennid
# Jenny Zhang
# Jephs Daring
# Jerick
# Jerono
# Jeshishin
# Jeshua Weight
# Jess
# Jest
# Jevena
# Jewels
# Jezrien
# Jial
# Jin
# Jix
# Jlan
# Joan Sheldon
# Jochi
# Joel Saxon
# John
# Johnst
# Jom
# Jon Acron
# Jon Deadfinger
# Jonathan Gentry
# Jonathan Phaedrus
# Jone
# Jonnes
# Jor
# Jordis
# Joret
# Jorgen Weight
# Jori
# Jorna
# Jors
# Joseph
# Joshin Yomen
# Joshor
# Jost
# Jub Hending
# Judy Ivans
# Jule
# Junmi
# Juno
# Jushu Davar
# Justin
# Ka
# Kabsal
# Kadash
# Kahar
# Kai-garnis
# Kairominas
# Kaise
# Kaladin
# Kalak
# Kalami
# Kalana
# Kalanor
# Kale Tekiel
# Kalishor
# Kalyani
# Kamali
# Kamiko
# Kangchenjunga Sarekgjakka
# KanPaar
# Kaplan
# Kar (Scadrial)
# Kar (Taldain)
# Kara
# Karata
# Karavaniga
# Kareien
# Karith Marvudi
# Karkun
# Karm
# Kasimarlix
# Katarotam
# Kath
# Kauri
# Kaves Kholin
# Kaza
# Kazan Smedry
# Kazilah
# Kdralk
# Ked
# Kef'ha
# Kel
# Kelerand
# Kelesina Shores
# Kelesina Shores's steward
# Kelin
# Kellen
# Kelsier
# Kelsier's mother
# Ken Harris
# Kenton
# Kenton's mother
# Kern
# Keseg
# Keshdel
# Kessi
# KeSun
# Ketol
# Kevoux
# Khav
# Khem
# Khen
# Kheni
# Khrissalla
# Khyan
# Ki
# Kiin
# Kilimanjaro
# Kim
# Kimmalyn
# Kinaler
# Kindwinds
# Kip
# Klade
# Klisn
# Kliss
# Kmakl
# Kmakra
# Knoxx
# Koen
# Kokerlii
# Koolf
# Koorm
# Korabet
# Korater
# Korath
# Koravellium Avast
# Kraisis
# Krent
# Kristir
# Kryst
# Kstled
# Kuma'tiki
# Kuno
# Kurdon
# Kurshina
# Kusiri
# Kwaan
# Kwashim
# Kwati
# Kyle Walters
# Kylrm
# Kyndlip Ternavyl
# Kyril
# Ladent
# Lady Alami
# Lady Farthing
# Lady Faula
# Lady Gardre
# Lady Lavont
# Lady Lentin
# Lady Mulgrave
# Lady Patresen
# Lady ZoBell
# Laggart
# Lahar
# Laird
# Lakin
# Lalai
# Lamaril
# Lamentation Winebare
# Lanacin
# Landras
# Landre
# Langor
# Languish
# Lani
# Lanna Write
# Laral Roshone
# Laran
# Laresh
# Larn (Roshar)
# Larn (Scadrial)
# Larskpur
# Lawkins
# Layton
# Lead
# Leavenworth Smedry
# Ledder
# Lee
# Leef
# LeeMar
# Leiko
# Leland Libel
# Lellin
# Lem
# Lemex
# Lemex's nurse
# Lenehe
# Leonard
# Leras
# Leroy
# Lesan Calour
# Leshwi
# Letmere
# Leven
# Levrin
# Leyten
# Lezian
# Lhan
# Lhanin
# Libby Smedry
# Lichfather
# Lieutenant Ahlstrom
# Lifeblesser
# Lifeforce
# Lifeline
# Lift
# Liganor
# Lightning
# Lili
# Lilly Whiting
# Lily
# Limmi
# Lin Davar
# Lin Yang-Tanasin
# Linji
# Liquidyne
# Lirin
# Liss
# Litima
# Liza
# Llarimar
# Loaten
# Loats
# Lokkall
# Lokmlen
# Lolan
# Lomard
# Lond
# Longbrow
# Longshadow
# Longshot
# Loophole
# Lopen
# Lopen's mother
# Loradar Vamah
# Lorain
# Lord Barrington
# Lord Canton
# Lord Erikell
# Lord Habren
# Lord Haltep
# Lord Hue
# Lord Steming
# Lord Stenet
# Loren
# Lorenzo
# Lorn
# Lotari
# Lovestruck
# Lua
# Luc
# Luesh
# Lukel
# Lulu
# Lusintia
# Lustow
# Luten
# Lyn
# Lyndel
# Lyndip
# Lyon
# M-Bot
# Ma
# Maare
# Mab
# Maben
# Mabrow Pigherder
# Macil
# Macob
# Madam Penfor
# Madasa
# Magna
# Mrs. Maheras
# Mai
# Maib
# Mailey
# Maindew
# Makal
# Makepeace Hapshire
# Makh
# Makkek
# Maksim
# Malad-son-Zent
# Malal
# Malan
# Malasha Seveks
# Malata
# Malchin
# Malcom
# Malise Gevelmar
# Malli
# Mallory
# Malmahan
# Malop
# Manaline
# Manuel Estevez
# Maod
# Maps
# Mara (Roshar)
# Mara (Skyward)
# Maraga Dulcet
# Marakal
# Marasi Colms
# Maratham
# Maraya
# Marci
# Marco
# Marcy
# Mardra
# Mare
# Mareshe
# Marf
# Margaret Libel
# Margel
# Mari Hammondess
# Maria
# Marinda
# Marks (Dreamer)
# Marks (Roshar)
# Marksman
# Marni
# Marple
# Marri
# Marsh
# Mart
# Martha
# Marthin
# Martra
# Mary Isenhorn
# Mary Mitchell
# Mary Rowlandson
# Masha-daughter-Shaliv
# Masly
# Matain
# Mathingdaw
# Matieu
# Matisse
# Matthew Cobb
# Matthew Jordan
# Maurin
# Maxillium Ladrian
# Maxin
# May Aladar
# Mayalaran
# Mazish
# Meala
# Mederia
# Megan
# Megan Tarash
# Mehen
# Meirav
# Mel
# Mela
# MeLaan
# Melali
# Melend Liese
# Meleran Khal
# Melhi
# Melishi
# Mellis
# Melloni
# Melody Muns
# Melu
# Mem
# Mennis
# Mercystar
# Mereline
# Meridas Amaram
# Merit
# Mesh
# Mi Won
# Mi'chelle Yomen
# Miasal
# Michael
# Midge
# Migs
# Mik
# Mikaff
# Mikaim
# Mikels
# Miklin
# Mil
# Milen Davenpleu
# Miles Dagouter
# Milev
# Miliv
# Mill
# Millhaven Smedry
# Milp
# Minara
# Ministara
# Mink (Alcatraz)
# Mintez
# Mirabell
# Mirris
# Mirthgiver
# Misel
# Mishinah Bethab
# Misra
# Miss Grimes
# Missouri Williams
# Halex
# Mitosis (Epic)
# Mizthla
# Moash
# Modicarm
# Moelach
# Molinar
# Molly (Perfect State)
# Molly (Snapshot)
# Monica
# Moratel
# Mord
# Morriumur
# Mosaic
# Moshe
# Motif
# Mraize
# Mrall
# Mrs. Chamwit
# Mrs. Cornelius
# Mrs. Hutchen
# Mrs. Nock
# Mrs. Saxon
# Mrs. Vmeer
# Mrun
# Mungam
# Mura
# Muri
# Murk
# Murkwood
# Murnbru
# Mustaches
# Myalmr
# N'Teese
# Nacomb Gaval
# Nafti
# Naga
# Naget
# NaiMeer
# Nakal
# Naladan
# Nalanar
# Nale
# Nalem
# Nall
# Nalma
# Nam
# Namar
# Nanalis
# Nananav
# NanHar
# Nanhel Eltorv
# NanKhet
# Nanrovah
# Naolen
# Narm
# Nashan
# Natam
# Natata Ved
# Natem
# Nathan Haight
# Natir
# Navani Kholin
# Navar
# Naze-daughter-Kuzodo
# Nazrilof
# Ned
# Nedd Strong
# Nem
# Nenefra
# Neoden
# Neon
# Nergaoul
# Neshan
# Neteb
# Neturo-son-Vallano
# New kid
# Newton
# Ng
# Ngozi
# Niali
# Nicelle Sauvage
# Night Known
# Night's Sorrow
# Night's Whisper
# Nightblood
# Nightingale
# Nightstorm pilot seven
# Nightwatcher
# Nightwielder
# Nikka
# Nikliasorm
# Nikolin
# Nissiqqan
# Nistar
# Niter
# Nlan
# Nlent
# Nohadon
# Noorden
# Norby
# Nord
# Noril
# Noromin
# Nose
# Notum
# Noura
# Nouxil
# Nuluba
# Numiga
# Lunamor
# Nydora
# Nyen
# O'Brien
# Obliteration
# Officer Dobbs
# Ohz Burtim Winzik
# Old Chapps
# Olid
# Olin Tober
# Oliver
# Omal
# Omin
# Oolelen
# Opa
# Opais
# OreSeur
# Ornament
# Oroden
# Orson Ansed
# Owen
# Paalm
# Paclo
# Pai
# Paige
# Pailiah
# Pakson
# Pal
# Paladar
# Palona
# Pama
# Pandri
# Panos Maheras
# Parik
# Parlin
# Pars
# Patji (being)
# Pattern
# Pattywagon Smedry
# Paul Crew
# Paul Tanasin
# Paxen
# Peaceyearning
# Pedin
# Peet
# Peg
# Penelope Portreau
# Pepe
# Perel
# Peret
# Perethom
# Perez
# Peterton
# Peterus
# Petrine
# Phendorana
# Phi
# Philen Frandeu
# Pielle Fromed
# Pink Pinkness
# Pipsqueak
# Pitt
# Placini
# Plamry
# Pleadix
# Pluv
# Poloni
# Powder
# Prasanva
# Praxton
# Princess of Dormancy
# Pull
# Punio
# Push
# Puuli
# Puños de Fuego
# Pyke
# Quellion
# Quentin Smedry
# Quilan
# Raagent
# Rabies
# Raboniel
# Radathavian
# Radrian Blackburn
# Rahul
# Raksha
# Ral
# Ral-na
# Ralinor
# Rally
# Rame Maldor
# Ramear
# Ranette
# Raninor
# Raoden
# Raoden's mother
# Raoshem
# Rariv
# Rasgor
# Rashek
# Rastik
# Raul
# Rayse
# RayZed
# Razal
# Re-Shephir
# Rebecca
# Red (Roshar)
# Red (Scadrial)
# Red Okongo
# Red Young
# Redalevin
# Redd
# Reddi
# Redeen
# Redin
# Redleaf
# Reen
# Reendel
# Reenst Rile
# Reesh
# Refractionary
# Regalia
# Relador
# Relina
# Relis Ruthar
# ReLuur
# Rem
# Remala
# Remark
# Rembrinor
# Remin
# Remmingtel Tarcsel
# Ren
# Renarin Kholin
# Rencalt
# Rene
# Rennold Pharl
# Replar Innate
# Reral Makoram
# Reshelle Tekiel
# Resi
# Reven
# Revilar
# Revokation
# Reya
# Rez
# Riah
# Rial
# Rian
# Rian Strobe
# Richardson Matthews
# Rick O'Shea
# Rick Stranger
# Ridger
# Riely
# Rien
# Riika
# Riil
# Riina
# Riino
# Rikers Dartmoor
# Rikolfr
# Rill
# Rilla
# Rillir Roshone
# Rin
# Rinakin
# Rind
# Rindel
# Rine
# Rine Hatham
# Rira (character)
# Ristina
# Rite
# Rittle
# Rlain
# Robin
# Rock (junior)
# Rod (Lumar)
# Rod (Roshar)
# Rodge McCaffrey
# Rodrayo
# Rodriguez
# Roger
# Roial
# Roion
# Roion's son
# Ron
# Rose (Reckoners)
# Rose (Rithmatist)
# Rothan
# Roy
# Roy Sheldon
# Roy Stephens
# Rtich (Epic)
# Rua
# Rudd
# Ruddy
# Ruli
# Ruri
# Rushu
# Rushur Kris
# Rusko
# Rust Elthal
# Ruthar
# Rysn Ftori
# Sadees
# Sadie
# Sah
# Sak
# Sakin
# Sakisa
# Salay
# Salay's father
# Salic
# Salinor Eved
# Salmen Tekiel
# Sam (Reckoner)
# Sam (vendor)
# Sand Lord
# Sandra
# Sani
# Saolin
# Sarene
# Sarene's mother
# Savrahalidem
# Sazed
# Scrak
# Screech
# Seaden
# Seala
# Sebasinar
# Sebruki
# Seeli
# Seinalan
# Sekeir
# Seland
# Selvest Vif
# Semm
# Senator Vindel
# Senna
# Sennion Crestmar
# Seor
# Sergeant Graves
# Sertes
# Serugiadis
# Sev
# Shaday
# Shadowblight
# Shalash
# Shale
# Shallan Davar
# Shallan's mother
# Shan Elariel
# Shan Elariel's steward
# ShanVen
# Shaor
# Shar
# Sharefel
# Shashara
# Shasta Smedry
# Shauka-daughter-Hasweth
# Shayna
# Shazarad
# She Who Dreams
# Sheler
# Shewrman
# Shim
# Shiver
# Shiversting
# Shob
# Shoren
# Shuanor
# Shubalai
# Shubreth-son-Mashalan
# Shuden
# Shum
# Shumin
# Si
# Sibling
# Sidin
# Sigzil
# Silajana
# Silence Montane
# Silence's grandfather
# Silence's grandmother
# Silversmith
# Simol
# Sinaku'a
# Sinbian
# Sindren
# Sindria
# Sing Sing Smedry
# Sir Squeekins
# Sir Ysla
# Sisirinah
# Sisisru
# Siv
# Sivi
# Sixteen
# Sixth of the Dusk (character)
# Sja-anat
# Skai
# Skar
# Skathan
# Skiff
# Skip
# Skyler
# Slingshot
# Slink
# Slowswift
# Smocke
# Smolderbrand
# Smta
# Snagu
# Snide
# Snowfall
# Snoxil
# Snuggles
# Sonic Snare
# Sonn
# Soomi
# Sophi Tarcsel
# Sophie (Reckoners)
# Sor
# Sot
# Sourcefield
# Sousa
# Spanky
# Spark
# Spears
# Spensa Nightshade
# Spensa's great-grandfather
# Spensa's great-grandmother
# Spensa's mother
# Spook
# Spritzer
# Squeeze
# Sssizme
# Stagin
# Stallion
# Stanoux
# Stansi
# Stanton
# Star
# Starfalls Stoneward
# Starfalls Windrunner
# Stargyle
# Stase Blanches
# Staxles
# Steadman
# Steelheart (Epic)
# Stefan Sauvage
# Lightsong
# Stephen Leeds
# Steris Harms
# Steve
# Stewart
# Stilla
# Stillmark
# Stine
# Stivient
# Stoff
# Stone Tie
# Stormfather
# Stormsummoner
# Stormwind (Epic)
# Stormy
# Straff Venture
# Strife
# Strongtower
# Sudi Valam
# Sullik
# Suna
# Suna (Roshar)
# Sur Kamar
# Sureblood
# Susebron
# Susebron the Fourth
# Susebron's mother
# Sushi
# Svel
# Swing
# Syasikk
# Sylphrena
# Sylvia
# Szeth
# Szeth's highspren
# Taan
# Tabaar
# Tadet
# Taff
# Taffa
# Tag
# Tai
# Taid
# Tain
# Taka
# Talak
# Talakimallo
# Talanah
# Talanan
# Talanor
# Talata
# Talatin
# Taleb
# Talenel
# Talik
# Tallan
# Talnah
# Tanalan
# Tanalan's father
# Tanalan's mother
# Tanavast
# Tao
# Taraco
# Tarah
# Taran
# Taravangian
# Taravangian's granddaughter
# Tarilar
# Tark Vestingdow
# TarKavv
# Tarn
# Tarson
# Tase
# Taselin
# Tashlin
# Tasinar
# Tatara
# Tathed
# Taudr
# Tavi
# Tavinar
# Tawnson
# Tearim
# Teft
# Tegas
# Telden Hasting
# Teleb
# Telesh
# Tellingdwar
# Telrii
# Telsin Ladrian
# Temadre
# Templeton Fig
# Ten
# Tenathar
# Tendel
# Tenrao
# TenSoon
# Teofil
# Teor
# Teorn
# Tepper
# Terarn
# Terion
# Terith
# Terms
# Terri
# Terrier
# Terxim
# Teshav Khal
# Teshav's ward
# Testament
# Teur
# Teven Renoux
# Tevidian Tekiel
# Thaddius
# Thadwick
# Thakka
# Thame
# Thanadal
# Thaspic
# Thaub
# The Photographer
# TheGannon
# Themos Tresting
# Theopolis
# Thered
# Theron
# Thior
# Thomas
# Thomas York
# Thomton Delacour
# Three-Tooth Dag
# Thresh-son-Esan
# Thude
# Thurts
# Tia
# Tibon
# Tien
# Tifandor
# Tifi
# Tift
# Tigzikk
# Tiil
# Tillaume
# Tim Vashin
# Timbre
# Tinalar
# Tindwyl
# Tindwyl Ladrian
# Tiqqa
# Tisark
# Tivbet
# Tizmar
# Tlik
# Tobal Copper
# Tobias
# Tobias (Threnody)
# Toh
# Tomor
# Ton (singer)
# Ton (Veden)
# Tonk Fah
# Tony
# Took
# Toorim
# Toral
# Toralin Roshone
# Toravi
# Torena
# Torfin
# Torkel
# Tormas
# Torol Sadeas
# Ms. Torrent
# Tozbek
# Traiben
# Trap
# Traxil
# Trebor
# Treff
# Treledees
# Trell (Trellism)
# Trell (Taldain)
# Tren-Pedri Delouse
# Trendalan
# Trent Saxon
# Trentison
# Tress
# Trey
# Triss
# Troalin
# Troubeld
# Truthcall
# Tsa
# Tshadr
# Tuaka
# Tuft
# Tukari leader
# Tukks
# Tumi
# Tumul
# Tunestone
# Turash
# Turinad Sebarial
# Turlm
# Turquoise
# Tusa
# Tvlakv
# Twist
# Ty
# Tyden
# Tyn
# Tzentian
# Tzoctinatin
# Ua'pam
# Ukrit
# Ulaam
# Ulan
# Ulba
# Ulef
# Uli Da
# Ulim
# Ulina
# Ulvlk
# Unativi
# Underscore
# Unoqua
# Ur (character)
# Urad
# Urdree
# Urialin
# Uriam
# Urian
# Urimil
# Urv
# Uscri
# Ushnaka
# Vaceslv
# Vadam
# Vahnn
# Vahr
# Vai
# Vaiu
# Valam
# Valama
# Valda Mendez
# Valentine
# Valette Entrone
# Vandonas
# Vapor
# Varala
# Varanis
# Varas
# VaraTreledees
# Vardinar
# Varion Crestmar
# Varlance
# Varnali
# VarSell
# Varth
# Vartian
# Vasher
# Vathah
# Vathe
# Vathi
# Vatwha
# Vazrmeb
# Ved (Skyward)
# Ved (Stormlight)
# Vedekar Perel
# Vedel
# Vedlew
# Vedzan
# Velalant
# Velat
# Velinar
# Ven
# Venan
# VenDell
# Venkohl
# Venli
# Vennis Hasting
# Vent (Scadrial)
# Vent (Skyward)
# Veratorim
# Verdant King
# Vershad
# Human
# Vespan
# Vet (Roshar)
# Vet (Scadrial)
# Vevanara
# Vevidar
# Vexil
# Vey
# Vigor
# Vila Mecant
# Vin
# Vin's mother
# Vin's sister
# Virginia
# Vishwadhar
# Vivenna
# Vivenna's Blade
# Vivenna's mother
# Vldgen
# Vlep
# Vlxim
# Vo
# Vod
# Voidsplitter
# Vono
# Vormel
# Vrandl
# Vratim
# Vstim
# Vwafendal
# Waber
# Wade
# Waffle
# Walin
# Wan ShaiLu
# Waren
# Warren
# Waterlog
# Waxillium Ladrian
# Wayne
# Wayne's mother
# Weatherlove
# Wednegon
# Weedfingers
# Weev
# Wellen
# Wellid
# Wells
# Wema
# Wenda Smith
# Westweather Cett
# Whiskers
# Wikim Davar
# Wilhelmette
# William Ann Montane
# William Montane
# William Muns
# Wilson
# Winds
# Wingflare
# Wink
# Winnow (Roshar)
# Winnow (Skyward)
# Winsting Innate
# Winter
# Wiper
# Wistiow
# Wmlak
# Wooden Soul
# Word of Deeds
# Wulfden the First
# Wulfden the Fourth
# Wvlan
# Wyndle
# Wyrn (character)
# Wzmal
# Xavier
# Xisisrefliel
# Yaalani
# Yake
# Yalb
# Yallard
# Yanagawn
# Yancey Yaceczko
# Yara
# Yarda
# Yazad
# Yeden
# Yelamaiszin
# Yelig-nar
# Yenev
# Yestal
# Yesteel
# Yezriar
# Yil
# Yis
# Yix
# Yixli
# Ym
# Yokska
# Yol Chay
# Yonatan
# Ytves
# Yulip
# Yunfah
# Yushah
# Yustara
# Zahel
# Zandiel
# Zane Venture
# Zedzil
# Zeen Nightshade
# Zeff
# Zeheb
# Zellion
# Zen Rigby
# Zen-daughter-Vath
# Zendid
# Zentu
# Zetah
# Zezin
# Ziming
# Zing
# Zoba Moss
# Professor ZoBell
# Zoran Tanasin
# Zu (Roshar)
# Zu (Sel)
# Zuln
# Zyardil
# Content
# English
# Not logged in
# Talk
# Contributions
# Create account
# Log in
# Category
# Discussion
# Read
# Edit
# History
# Home
# Chat
# Recent Changes
# Random Page
# Guides and Policies
# Editor's Corner
# Time Machine
# Books
# Characters
# Culture
# Events and Eras
# Lifeforms
# Locations
# Magic
# Objects and Materials
# Cosmere
# Cytoverse
# 17th Shard
# Forums
# Arcanum
# What links here
# Related changes
# Special pages
# Printable version
# Permanent link
# Page information
#  This page was last edited on 22 May 2022, at 04:07.
# Content is available under CC4 by-nc-nd unless otherwise noted.
# About The Coppermind
# Mobile view

# %% [markdown]
# So now that we can get the characters's names, we want to give it the correct starting point. here we'll use the `soup.find` function, and after using the 'Inspect' function on the browser, we know we're looking for the `div` element with `id='mw-pages'`. If we save this as `section`, we can then use this section of the website, combined with the code from above to collect a list of all of the names of Brandon Sanderson characters.

# %%
section = soup.find('div', id='mw-pages') # 

count = 0

for li in section.find_all('li'):
  count = count + 1
  name = li.text
  
  #print the first few lines just to make sure it looks good
  if count < 10: 
    print(count, name)

  #add some other information to the csv file.
  author = 'Brandon Sanderson'
  genre = 'fantasy'
  series = ''
  description =''
  csv_writer.writerow([name, author, genre, series, description])
# Out:
# 1 Aarik
# 2 Aaron
# 3 Abaray
# 4 Abiajan
# 5 Abigail Casey
# 6 Abraham Desjardins
# 7 Abrem
# 8 Abrial
# 9 Abrobadar

# %% [markdown]
# ## Now let's add some Wheel of Time:
#
# New URL: https://en.wikipedia.org/wiki/List_of_Wheel_of_Time_characters
#
# You'll notice that the way this website is set up is a bit different from the Brando Sando website. We'll have to adjust our web-scarping code accordingly.

# %%
source = requests.get('https://en.wikipedia.org/wiki/List_of_Wheel_of_Time_characters').text

soup = BeautifulSoup(source, 'html.parser')
section = soup.find('div', class_='mw-parser-output')

count = 0
for li in section.find_all('li'):

  #This one isn't quite as simple becuase we have a character name and description.
  count = count + 1
  list_item = li.text

  #not all of the entries are names, but all the names follow the syntax <name: description>  
  if(len(list_item.split(':'))>1): 
    name= list_item.split(':')[0]  #The first element is the name so we use [0]
    description = list_item.split(':')[1] #the description is after the :, so we use [1]


    # SPOILER ALERT: DONT PRINT DESCRIPTION OUT IF YOU DON'T WANT TO READ THE CHARACTER DESCRIPTIONS.
    if count < 10:
      print(count, name)

    #then we add some other information and write a row to the csv file
    series = 'Wheel of Time'
    author = 'Robert Jordan'
    genre= 'fantasy'
    csv_writer.writerow([name, author, genre, series, description])
# Out:
# 1 Logain Ablar
# 2 Jonan Adley
# 3 .mw-parser-output .vanchor>
# 4 Dermid Ajala
# 5 Lelaine Akashi
# 6 Nalesean Aldiaya
# 7 Algarin Pendaloan
# 8 Alivia
# 9 Katerine Alruddin

# %% [markdown]
# ## How about some Kingkiller Chronicles Characters
# https://kingkiller.fandom.com/wiki/Category:Characters

# %%
source = requests.get('https://kingkiller.fandom.com/wiki/Category:Characters').text

soup = BeautifulSoup(source, 'html.parser')
section = soup.find('div', class_ = 'category-page__members')


count = 0
for li in section.find_all('li'):
    count = count+1
    list_item = li.text.strip()
    if len(list_item.split(':')) == 1:
      #print(list_item.strip())


    #then we add some other information and write a row to the csv file
      name = list_item.strip()
      series = 'Kingkiller Chronicles'
      author = 'Patrick Rothfuss'
      genre= 'fantasy'
      csv_writer.writerow([name, author, genre, series, description])

# %% [markdown]
# ## Lord of the Rings, Anyone?
# Yesss, my preciousssss: https://lotr.fandom.com/wiki/Category:The_Lord_of_the_Rings_Characters

# %%
source = requests.get('https://en.wikipedia.org/wiki/Category:The_Lord_of_the_Rings_characters').text

# And try to do Lord of the Rings also

# %% [markdown]
# # Annnnddd... let's give that bad boy a download

# %%
csv_file.close()
from google.colab import files
files.download('fantasy_characters.csv')
